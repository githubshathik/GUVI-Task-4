# %% [markdown]
# <a href="https://colab.research.google.com/github/githubshathik/GUVI-Task-4/blob/shathik/GUVI_task4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# GUVI -IITM Advance programming and Master data science
#
# Name:Mohamed Shathik
#
# mail id:mohamedshafa17@gmail.com
#
# Task no:4
#
# Batch:D10(B)

# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
data1=pd.read_csv("/content/college_1.csv")
data1
# Out:
#               Name  python  ...                              Department  Rising
# 0        A.Dharani    82.0  ...        Computer Science and Engineering       0
# 1      V.JEEVITHA     82.0  ...        Computer Science and Engineering       0
# 2      HEMAVATHI.R   100.0  ...        Computer Science and Engineering       0
# 3      Mugunthan S   100.0  ...        Computer Science and Engineering       0
# 4      Sathammai.S   100.0  ...        Computer Science and Engineering       0
# ..             ...     ...  ...                                     ...     ...
# 79    KarthikeyanS    45.0  ...  Electronics and Electrical Engineering       0
# 80        BARATH.P    29.0  ...  Electronics and Electrical Engineering       0
# 81   N.Ajith kumar    82.0  ...  Electronics and Electrical Engineering       0
# 82    mohamed nabi     0.0  ...  Electronics and Electrical Engineering       0
# 83  yaser ahamed.A     0.0  ...  Electronics and Electrical Engineering       0
#
# ...

# %%
d1=pd.DataFrame(data1)
d1
# Out:
#               Name  python  ...                              Department  Rising
# 0        A.Dharani    82.0  ...        Computer Science and Engineering       0
# 1      V.JEEVITHA     82.0  ...        Computer Science and Engineering       0
# 2      HEMAVATHI.R   100.0  ...        Computer Science and Engineering       0
# 3      Mugunthan S   100.0  ...        Computer Science and Engineering       0
# 4      Sathammai.S   100.0  ...        Computer Science and Engineering       0
# ..             ...     ...  ...                                     ...     ...
# 79    KarthikeyanS    45.0  ...  Electronics and Electrical Engineering       0
# 80        BARATH.P    29.0  ...  Electronics and Electrical Engineering       0
# 81   N.Ajith kumar    82.0  ...  Electronics and Electrical Engineering       0
# 82    mohamed nabi     0.0  ...  Electronics and Electrical Engineering       0
# 83  yaser ahamed.A     0.0  ...  Electronics and Electrical Engineering       0
#
# ...

# %%
data2=pd.read_csv("/content/college_2.csv")
data2
# Out:
#                       Name  ...  Rising
# 0            ASHOK KUMAR K  ...       0
# 1                  Chandru  ...     340
# 2        Ganesh Ramkumar R  ...    2000
# 3          Bodipudi Harini  ...       0
# 4                VIINU V P  ...       0
# 5               Poojitha Y  ...    1760
# 6   Gowtham Chandrasekaran  ...    1700
# 7                Gowtham R  ...       0
# 8                 shifak N  ...    3140
# 9                  Balaji   ...    1990
# 10                Rushitha  ...     620
# 11    Balaraman Muthupandi  ...     380
# 12                JPradhap  ...     690
# 13           SRIRAMKUMAR B  ...    1540
# 14               Praneetha  ...     560
# 15             Rahul Raj K  ...    1360
# 16                 Guhan S  ...     320
# 17            Suryarajan S  ...     840
# 18          Narasimhan Y L  ...    2000
# 19            Leelakrishna  ...    1340
# 20          PremsagarReddy  ...    1000
# 21               pradeeban  ...      30
# ...

# %%
d2=pd.DataFrame(data2)
d2
# Out:
#                       Name  ...  Rising
# 0            ASHOK KUMAR K  ...       0
# 1                  Chandru  ...     340
# 2        Ganesh Ramkumar R  ...    2000
# 3          Bodipudi Harini  ...       0
# 4                VIINU V P  ...       0
# 5               Poojitha Y  ...    1760
# 6   Gowtham Chandrasekaran  ...    1700
# 7                Gowtham R  ...       0
# 8                 shifak N  ...    3140
# 9                  Balaji   ...    1990
# 10                Rushitha  ...     620
# 11    Balaraman Muthupandi  ...     380
# 12                JPradhap  ...     690
# 13           SRIRAMKUMAR B  ...    1540
# 14               Praneetha  ...     560
# 15             Rahul Raj K  ...    1360
# 16                 Guhan S  ...     320
# 17            Suryarajan S  ...     840
# 18          Narasimhan Y L  ...    2000
# 19            Leelakrishna  ...    1340
# 20          PremsagarReddy  ...    1000
# 21               pradeeban  ...      30
# ...

# %%
d1.describe()
# Out:
#            python      mysql  Previous Geekions  CodeKata Score      Rising
# count   84.000000   84.00000          84.000000       84.000000   84.000000
# mean    73.392857   27.60119        2904.523810     2906.071429    1.547619
# std     35.589280   36.30562        4372.425826     4374.184197   14.184163
# min      0.000000    0.00000           0.000000        0.000000    0.000000
# 25%     52.250000    0.00000         292.500000      292.500000    0.000000
# 50%     90.250000   11.62500        1580.000000     1580.000000    0.000000
# 75%    100.000000   41.00000        3727.500000     3727.500000    0.000000
# max    100.000000  100.00000       24500.000000    24500.000000  130.000000

# %%
d2.describe()
# Out:
#            python   python_en  ...  CodeKata Score       Rising
# count   35.000000   35.000000  ...       35.000000    35.000000
# mean     8.657143   29.657143  ...     6801.428571   708.285714
# std     25.795511   30.582524  ...     3765.281134   836.429687
# min     -1.000000   -1.000000  ...        0.000000     0.000000
# 25%     -1.000000    0.000000  ...     4630.000000     0.000000
# 50%     -1.000000   20.000000  ...     7550.000000   380.000000
# 75%     -1.000000   52.000000  ...     8240.000000  1350.000000
# max    100.000000  100.000000  ...    19400.000000  3140.000000
#
# [8 rows x 7 columns]

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
y=pd.concat([d1,d2],ignore_index=True)
y
# Out:
#               Name  python  mysql  ...  Rising  python_en computational_thinking
# 0        A.Dharani    82.0   20.0  ...       0        NaN                    NaN
# 1      V.JEEVITHA     82.0   20.0  ...       0        NaN                    NaN
# 2      HEMAVATHI.R   100.0  100.0  ...       0        NaN                    NaN
# 3      Mugunthan S   100.0   47.0  ...       0        NaN                    NaN
# 4      Sathammai.S   100.0    8.0  ...       0        NaN                    NaN
# ..             ...     ...    ...  ...     ...        ...                    ...
# 114  praveen raj j    24.0    0.0  ...       0       -1.0                    0.0
# 115     AMARNATH D    -1.0   12.0  ...       0       52.0                   -1.0
# 116           bala    32.0    0.0  ...       0       49.0                   -1.0
# 117           XY Z    -1.0   -1.0  ...       0       20.0                   -1.0
# 118      Hariharan    -1.0   -1.0  ...       0       -1.0                    0.0
#
# ...

# %%
y=pd.DataFrame(y)

# %%
y.describe()
# Out:
#            python       mysql  ...   python_en  computational_thinking
# count  119.000000  119.000000  ...   35.000000               35.000000
# mean    54.352941   23.500000  ...   29.657143                2.200000
# std     44.272526   33.276671  ...   30.582524                7.015948
# min     -1.000000   -1.000000  ...   -1.000000               -1.000000
# 25%      0.000000    0.000000  ...    0.000000                0.000000
# 50%     82.000000    4.000000  ...   20.000000                0.000000
# 75%    100.000000   33.000000  ...   52.000000                0.000000
# max    100.000000  100.000000  ...  100.000000               39.000000
#
# [8 rows x 7 columns]

# %%
y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119 entries, 0 to 118
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    119 non-null    object
#  1   python                  119 non-null    float64
#  2   mysql                   119 non-null    float64
#  3   Previous Geekions       119 non-null    int64
#  4   CodeKata Score          119 non-null    int64
#  5   Department              119 non-null    object
#  6   Rising                  119 non-null    int64
#  7   python_en               35 non-null     float64
#  8   computational_thinking  35 non-null     float64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 8.5+ KB

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %%
v=y[y['CodeKata Score']>15000]
v
# Out:
#              Name  python  mysql  ...  Rising  python_en computational_thinking
# 0       A.Dharani    82.0   20.0  ...       0        NaN                    NaN
# 1     V.JEEVITHA     82.0   20.0  ...       0        NaN                    NaN
# 2     HEMAVATHI.R   100.0  100.0  ...       0        NaN                    NaN
# 84  ASHOK KUMAR K   100.0   31.0  ...       0        0.0                    9.0
#
# [4 rows x 9 columns]

# %%
#v.to_csv('Exceeded expectations.csv')

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %%
p=y[(y['CodeKata Score']>10000)&(y['CodeKata Score']<15000)]
p
# Out:
#                  Name  python  mysql  ...  Rising  python_en computational_thinking
# 3         Mugunthan S   100.0   47.0  ...       0        NaN                    NaN
# 85            Chandru     0.0    0.0  ...     340       20.0                    0.0
# 86  Ganesh Ramkumar R    -1.0   24.0  ...    2000       55.0                    6.0
# 87    Bodipudi Harini    -1.0   35.0  ...       0        0.0                   -1.0
#
# [4 rows x 9 columns]

# %%
#p.to_csv('Reached_expectations.csv')

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %%
c=y[(y['CodeKata Score']>7000)&(y['CodeKata Score']<10000)]
c
# Out:
#                        Name  python  ...  python_en  computational_thinking
# 4               Sathammai.S   100.0  ...        NaN                     NaN
# 5              NIVEESHWAR S   100.0  ...        NaN                     NaN
# 6             KALAIARASAN K    85.0  ...        NaN                     NaN
# 7      MOHAMED ZUBAIR AHMED    82.0  ...        NaN                     NaN
# 88                VIINU V P    -1.0  ...      100.0                    -1.0
# 89               Poojitha Y     0.0  ...       78.0                     0.0
# 90   Gowtham Chandrasekaran    -1.0  ...        0.0                     3.0
# 91                Gowtham R    -1.0  ...       60.0                     6.0
# 92                 shifak N    58.0  ...        0.0                     0.0
# 93                  Balaji     -1.0  ...      100.0                     0.0
# 94                 Rushitha    -1.0  ...       15.0                     9.0
# ...

# %%
#c.to_csv('Needs_Improvement.csv')

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
a=y[y['CodeKata Score']<7000]
a
# Out:
#                 Name  python  mysql  ...  Rising  python_en computational_thinking
# 8         J.SUGANTHI    27.0  50.00  ...       0        NaN                    NaN
# 9       thamizhpaana    29.0   0.00  ...       0        NaN                    NaN
# 10   Iyappan Samiraj    50.0  24.00  ...       0        NaN                    NaN
# 11      Ponniyamma.R   100.0  11.25  ...       0        NaN                    NaN
# 12         SABAPATHI   100.0   0.00  ...       0        NaN                    NaN
# ..               ...     ...    ...  ...     ...        ...                    ...
# 114    praveen raj j    24.0   0.00  ...       0       -1.0                    0.0
# 115       AMARNATH D    -1.0  12.00  ...       0       52.0                   -1.0
# 116             bala    32.0   0.00  ...       0       49.0                   -1.0
# 117             XY Z    -1.0  -1.00  ...       0       20.0                   -1.0
# ...

# %%
#a.to_csv('Unsatisfactory.csv')

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
t=y['Previous Geekions'].mean()
t
# Out:
# 3842.3529411764707

# %%
o=y['CodeKata Score'].mean()
o
# Out:
# 4051.764705882353

# %%
m=o-t
m
# Out:
# 209.41176470588243

# %% [markdown]
# Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)
#
#
# CodeKata Score average is **209.41** more than previous
# geek coins

# %% [markdown]
# ###### No of students participated

# %%
e=y.count()
e
# Out:
# Name                      119
# python                    119
# mysql                     119
# Previous Geekions         119
# CodeKata Score            119
# Department                119
# Rising                    119
# python_en                  35
# computational_thinking     35
# dtype: int64

# %% [markdown]
# **119** students were participated in both colleges

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
h=y['mysql'].mean()
h
# Out:
# 23.5

# %%
l=y['computational_thinking'].mean()
l
# Out:
# 2.2

# %%
k=y['python_en'].mean()
k
# Out:
# 29.65714285714286

# %%
u=y['python'].mean()
u
# Out:
# 54.35294117647059

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)
# 1)**shifak N**
#
# 2)**Ganesh Ramkumar R**
#
# 3)**Narasimhan Y L**
#
# these are the three candidates rising stars of the week

# %%
f=y.sort_values(by = 'Rising',ascending = False)
f.head(3)
# Out:
#                   Name  python  ...  python_en  computational_thinking
# 92            shifak N    58.0  ...        0.0                     0.0
# 102     Narasimhan Y L    -1.0  ...       -1.0                     0.0
# 86   Ganesh Ramkumar R    -1.0  ...       55.0                     6.0
#
# [3 rows x 9 columns]

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)
# 1)**A.Dharani**
#
# 2)**V.JEEVITHA**
#
# 3)**HEMAVATHI.R**
#
# these are the three candidates shining stars of the week

# %%
s=y.sort_values(by = 'Previous Geekions',ascending = False)
s.head(3)
# Out:
#           Name  python  mysql  ...  Rising  python_en computational_thinking
# 0    A.Dharani    82.0   20.0  ...       0        NaN                    NaN
# 1  V.JEEVITHA     82.0   20.0  ...       0        NaN                    NaN
# 2  HEMAVATHI.R   100.0  100.0  ...       0        NaN                    NaN
#
# [3 rows x 9 columns]

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
y['Department'].describe()
# Out:
# count                                  119
# unique                                   3
# top       Computer Science and Engineering
# freq                                    63
# Name: Department, dtype: object

# %%
t1=(y['Department'].unique())
t1
# Out:
# array(['Computer Science and Engineering',
#        'Electronics and Communication Engineering',
#        'Electronics and Electrical Engineering'], dtype=object)

# %%
q1=y[y['Department']=="Computer Science and Engineering"]
s1=q1['CodeKata Score'].sum()
s1
# Out:
# 320025

# %%
q2=y[y['Department']=="Electronics and Communication Engineering"]
s2=q2['CodeKata Score'].sum()
s2
# Out:
# 108335

# %%
q3=y[y['Department']=="Electronics and Electrical Engineering"]
s3=q3['CodeKata Score'].sum()
s3
# Out:
# 53800

# %%
data=[s1,s2,s3]
  
# Creating plot
fig = plt.figure(figsize =(10, 7))
plt.pie(data, labels = t1,explode=(0.4,0,0.2),colors=['gold','blue','lightcoral'],autopct=('%1.1f%%'),shadow=True)
  
# show plot
plt.show()

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
n1=q1[q1['CodeKata Score']==q1['CodeKata Score'].max()]
n1
# Out:
#         Name  python  mysql  ...  Rising  python_en computational_thinking
# 0  A.Dharani    82.0   20.0  ...       0        NaN                    NaN
#
# [1 rows x 9 columns]

# %%
n2=q2[q2['CodeKata Score']==q2['CodeKata Score'].max()]
n2
# Out:
#                Name  python  mysql  ...  Rising  python_en computational_thinking
# 87  Bodipudi Harini    -1.0   35.0  ...       0        0.0                   -1.0
#
# [1 rows x 9 columns]

# %%
n3=q3[q3['CodeKata Score']==q3['CodeKata Score'].max()]
n3
# Out:
#              Name  python  mysql  ...  Rising  python_en computational_thinking
# 84  ASHOK KUMAR K   100.0   31.0  ...       0        0.0                    9.0
#
# [1 rows x 9 columns]

# %%
import matplotlib.pyplot as plt

x=['A.Dharani-CSE','Bodipudi Harini-ECE','ASHOK KUMAR K-EEE']

# giving the values against
# each value at x axis
y=[24500,10040,19400]
plt.bar(x, y)

# setting x-label as pen sold
plt.xlabel("Department wise toppers")

# setting y_label as price
plt.ylabel("codekata score")
plt.title("Vertical bar graph")

plt.show()
